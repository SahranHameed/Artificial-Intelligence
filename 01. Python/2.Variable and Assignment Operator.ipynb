# %%
# Addition of Two Numbers
num1 = 10
num2 = 20
final = num1 + num2 
print ("Final Answar is=")
print (final)
# Out:
# Final Answar is=
# 30

# %%
firstName = 'Mars'
lastName = 'Tech'
fullName = firstName + lastName
print(fullName)
# Out:
# MarsTech

# %%
# Addition with Variables
num1 = 10
num2 = 20
print("The Addition of Two Numbers")
print("The Number 1 is:",num1)
print("The Number 2 is:",num2)
print("The Answar is:",num1 + num2)
# Out:
# The Addition of Two Numbers
# The Number 1 is: 10
# The Number 2 is: 20
# The Answar is: 30

# %%
# If you get user input, the integer data type must be converted using int()
number1 = int(input("Enter The number1 :"))
number2 = int(input("Enter The number2 :"))

print (number1 + number2)
# Out:
# Enter The number1 : 30
# Enter The number2 : 70
# 100

# %%
# input() returns string data type by default
firstName = input("Enter your firstName: ")
lastName = input("Enter your lastName: ")

print("Your firstName is:", firstName)
print("You lastName is:", lastName)
# Out:
# Enter your firstName:  Hameed
# Enter your lastName:  Sahran
# Your firstName is: Hameed
# You lastName is: Sahran
