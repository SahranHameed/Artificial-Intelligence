# %%
#Print Syntax
print("")

# %%
print("Hello World")
# Out:
# Hello World

# %%
#Step1: Define numbers
num1 = 10
num2 = 20

#Step2: Add numbers
final = num1 + num2 
print ("Final Answer is =")

#Step2: Print numbers
print (final)
# Out:
# Final Answer is =
# 30
